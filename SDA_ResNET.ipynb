# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from tqdm import tqdm_notebook
import cv2

import keras
from keras.layers.convolutional import Conv2DTranspose
from keras.layers.merge import concatenate
from keras.layers import UpSampling2D, Conv2D, Activation, Input, Dropout, MaxPooling2D
from keras import Model
from keras import backend as K
from keras.layers.core import Lambda
from collections import defaultdict
from sklearn.model_selection import train_test_split
import pandas as pd

import random

import tensorflow as tf
from tensorflow import reduce_sum
from tensorflow.keras.backend import pow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, UpSampling2D, Concatenate, Add, Flatten
from tensorflow.keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Get Data

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path = '/content/drive/My Drive/project/data_main/'

# %%
train_img = path + "train_images"

# %%
train_data  = pd.read_csv(path + '/train.csv')
print("Length of train data", len(train_data))
# Out:
# Length of train data 50272

# %%
# Pivot the data
df = pd.read_csv(path + '/train.csv')
df['ImageId'], df['ClassId'] = zip(*df['ImageId_ClassId'].str.split('_'))
df['ClassId'] = df['ClassId'].astype(int)
df = df.pivot(index='ImageId',columns='ClassId',values='EncodedPixels')
df['defects'] = df.count(axis=1)
# Divide the data 
train_df, val_df = train_test_split(df, test_size=0.2, stratify=df["defects"], random_state=69)

# %%
train_df = train_df.reset_index()
train_df = train_df.reset_index()

val_df = val_df.reset_index()
val_df = val_df.reset_index()

# %%
# For class imbalance, we need to use the data witout nulls.
df_no_null = train_data[train_data['EncodedPixels'].notnull()].reset_index(drop=True)
 
print("Lenght of training data " , len(train_df))
print("Lenght of validation data " , len(val_df))
# Out:
# Lenght of training data  10054
# Lenght of validation data  2514

# %% [markdown]
# # Pre-process data

# %%
def mask2rle(img):
    '''
    For an ouput numpy array
    1  == Mask, 
    0  == background
    Returns run length as string formated
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
def make_mask(row_id, df):
    '''
    Given a row index, 
    return a image id and mask of the image in the format of (256, 1600, 4)
    from the dataframe `df`
    '''

    masks = np.zeros((256, 1600, 4), dtype=np.float32)     
    labels = df.iloc[row_id][2:-1]
    for idx, label in enumerate(labels.values):
        if label is not np.nan:
            label = label.split(" ")
            positions = map(int, label[0::2])
            length = map(int, label[1::2])
            mask = np.zeros(256 * 1600, dtype=np.uint8)
            for pos, le in zip(positions, length):
                mask[pos:(pos + le)] = 1
            masks[:, :, idx] = mask.reshape(256, 1600, order='F')
    return masks

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, df, image_dir, batch_size=16,
                 img_h=256, img_w=256, shuffle=True):
        
        self.df = df
        self.image_dir = image_dir
        self.batch_size = batch_size
        self.img_h = img_h
        self.img_w = img_w
        self.shuffle = shuffle
        self.on_epoch_end()
    
    def __len__(self):
        'denotes the number of batches per epoch'
        return int(np.floor(len(self.df)) / self.batch_size)
    
    def __getitem__(self, index):
        'generate one batch of data'
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # get list of IDs
        list_ids_temp = indexes
        # generate data
        X, y = self.__data_generation(list_ids_temp)
        # return data 
        return X, y
    
    def on_epoch_end(self):
        'update ended after each epoch'
        self.indexes = np.arange(len(self.df))
        if self.shuffle:
            np.random.shuffle(self.indexes)
            
    def __data_generation(self, list_ids_temp):
      img_size = 256
      x_batch = []
      y_batch = []
      for id in list_ids_temp: 
          # Get the image
          image_name = self.df['ImageId'].iloc[id]
          image = cv2.imread(self.image_dir  + 'train_images/'+image_name)
          image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
          # Get the mask 
          mask = make_mask(id, self.df)
          # Resize 
          image = cv2.resize(image, (img_size, img_size))
          mask = cv2.resize(mask, (img_size, img_size))
          # Add 
          x_batch += [image]
          y_batch += [mask]
      # Change to numpy                   
      x_batch = np.array(x_batch)
      y_batch = np.array(y_batch)
      return x_batch, y_batch

# %%
training_generator = DataGenerator(train_df, path)

# %%
validation_generator = DataGenerator(val_df, path)

# %%
def class_imbalance(df): 
  '''
  To treat for class imbalance, we will be using this function
  '''
  # Get the data, arrange it in classes 
  df['ImageId'], df['ClassId'] = zip(*df['ImageId_ClassId'].str.split('_'))
  df['ClassId'] = df['ClassId'].astype(int)
  df = df.pivot(index='ImageId',columns='ClassId',values='EncodedPixels')
  df['defects'] = df.count(axis=1) 
  # Get the number of mask in each class 
  list_all = list(df.count())[: -1]
  sum_list_all = sum(list_all) 
  return [list_all[i]/sum_list_all * 4  for i in range(len(list_all))]

# %% [markdown]
# # Model

# %%
def dsc(y_true, y_pred, smooth=1):
    '''
    Get the dice coefficiant of two oututs 
    '''
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth) 
  
def dice_loss(y_true, y_pred):
    '''
    Get the loss 
    '''
    loss = 1 - dsc(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    '''
    Get the loss
    '''
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
def bn_act(x, act=True):
    'batch normalization layer with an optinal activation layer'
    x = tf.keras.layers.BatchNormalization()(x)
    if act == True:
        x = tf.keras.layers.Activation('relu')(x)
    return x

def conv_block(x, filters, kernel_size=3, padding='same', strides=1):
    'convolutional layer which always uses the batch normalization layer'
    conv = bn_act(x)
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv
  
def stem(x, filters, kernel_size=3, padding='same', strides=1):
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size, padding, strides)
    shortcut = Conv2D(filters, kernel_size=1, padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    output = Add()([conv, shortcut])
    return output 
  
def residual_block(x, filters, kernel_size=3, padding='same', strides=1):
    res = conv_block(x, filters, k_size, padding, strides)
    res = conv_block(res, filters, k_size, padding, 1)
    shortcut = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    output = Add()([shortcut, res])
    return output 
  
def upsample_concat_block(x, xskip):
    u = UpSampling2D((2,2))(x)
    c = Concatenate()([u, xskip])
    return c 
  


def ResUNet(img_h, img_w):
    f = [16, 32, 64, 128, 256]
    inputs = Input((img_h, img_w, 3))
    
    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)
    
    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)
    
    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = tf.keras.layers.Conv2D(4, (1, 1), padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs)
    return model

# %%
k_size = 3
model = ResUNet(img_h=256, img_w= 256)
adam = tf.keras.optimizers.Adam(lr = 0.05, epsilon = 0.1)
model.compile(optimizer=adam, loss=bce_dice_loss, metrics=[dsc])
#model.load_weights(path + 'ResUNetSteel_w800e50_z.h5')

# %% [markdown]
# # Test & Train

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint = ModelCheckpoint(path + 'model_best_weights_resnet.h5', monitor='loss', verbose=1, save_best_only=False, mode='min', period=1)

# %%
batch_size = 16
results = model.fit_generator(generator=training_generator, 
                              validation_data=validation_generator,
                              class_weight=class_imbalance(df_no_null),  
                              steps_per_epoch= 100,
                              epochs=50, callbacks = [checkpoint],)
# Out:
# Epoch 1/50
#  99/100 [============================>.] - ETA: 5s - loss: 0.9967 - dsc: 0.1132 Epoch 1/50
# 157/100 [===============================================] - 796s 5s/step - loss: 3.4375 - dsc: 0.0548
#
# Epoch 00001: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 1340s 13s/step - loss: 0.9976 - dsc: 0.1122 - val_loss: 3.4326 - val_dsc: 0.0548
# Epoch 2/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8776 - dsc: 0.1776Epoch 1/50
# 157/100 [===============================================] - 58s 368ms/step - loss: 1.6843 - dsc: 0.0606
#
# Epoch 00002: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 526s 5s/step - loss: 0.8788 - dsc: 0.1764 - val_loss: 1.7081 - val_dsc: 0.0606
# Epoch 3/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8731 - dsc: 0.1875Epoch 1/50
# 157/100 [===============================================] - 58s 367ms/step - loss: 1.1595 - dsc: 0.1009
#
# Epoch 00003: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 534s 5s/step - loss: 0.8738 - dsc: 0.1867 - val_loss: 1.1726 - val_dsc: 0.1009
# Epoch 4/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8321 - dsc: 0.2279Epoch 1/50
# 157/100 [===============================================] - 57s 365ms/step - loss: 0.9915 - dsc: 0.1304
#
# Epoch 00004: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 547s 5s/step - loss: 0.8332 - dsc: 0.2265 - val_loss: 1.0096 - val_dsc: 0.1304
# Epoch 5/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.7947 - dsc: 0.2596Epoch 1/50
# 157/100 [===============================================] - 57s 363ms/step - loss: 0.9077 - dsc: 0.1346
#
# Epoch 00005: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 528s 5s/step - loss: 0.7953 - dsc: 0.2591 - val_loss: 0.9190 - val_dsc: 0.1346
# Epoch 6/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.7546 - dsc: 0.2987Epoch 1/50
# 157/100 [===============================================] - 57s 364ms/step - loss: 0.8843 - dsc: 0.1398
#
# Epoch 00006: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 509s 5s/step - loss: 0.7554 - dsc: 0.2979 - val_loss: 0.9054 - val_dsc: 0.1398
# Epoch 7/50
#  99/100 [============================>.] - ETA: 1s - loss: 0.7141 - dsc: 0.3350Epoch 1/50
# 157/100 [===============================================] - 55s 350ms/step - loss: 0.8842 - dsc: 0.1817
#
# Epoch 00007: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 221s 2s/step - loss: 0.7156 - dsc: 0.3338 - val_loss: 0.8787 - val_dsc: 0.1817
# Epoch 8/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.7362 - dsc: 0.3166Epoch 1/50
# 157/100 [===============================================] - 55s 349ms/step - loss: 1.9010 - dsc: 0.0685
#
# Epoch 00008: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.7356 - dsc: 0.3176 - val_loss: 1.8415 - val_dsc: 0.0685
# Epoch 9/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.7439 - dsc: 0.3061Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.8337 - dsc: 0.2332
#
# Epoch 00009: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.7445 - dsc: 0.3055 - val_loss: 0.8276 - val_dsc: 0.2332
# Epoch 10/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.7122 - dsc: 0.3374Epoch 1/50
# 157/100 [===============================================] - 54s 344ms/step - loss: 0.6469 - dsc: 0.3737
#
# Epoch 00010: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.7102 - dsc: 0.3392 - val_loss: 0.6708 - val_dsc: 0.3737
# Epoch 11/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6883 - dsc: 0.3625Epoch 1/50
# 157/100 [===============================================] - 55s 347ms/step - loss: 0.8656 - dsc: 0.2443
#
# Epoch 00011: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6857 - dsc: 0.3648 - val_loss: 0.8312 - val_dsc: 0.2443
# Epoch 12/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6775 - dsc: 0.3690Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.7989 - dsc: 0.2489
#
# Epoch 00012: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6786 - dsc: 0.3681 - val_loss: 0.8400 - val_dsc: 0.2489
# Epoch 13/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6715 - dsc: 0.3788Epoch 1/50
# 157/100 [===============================================] - 55s 351ms/step - loss: 0.8817 - dsc: 0.2077
#
# Epoch 00013: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6711 - dsc: 0.3792 - val_loss: 0.9065 - val_dsc: 0.2077
# Epoch 14/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6491 - dsc: 0.3990Epoch 1/50
# 157/100 [===============================================] - 55s 349ms/step - loss: 0.7102 - dsc: 0.3330
#
# Epoch 00014: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6478 - dsc: 0.4001 - val_loss: 0.7172 - val_dsc: 0.3330
# Epoch 15/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6578 - dsc: 0.3888Epoch 1/50
# 157/100 [===============================================] - 56s 354ms/step - loss: 0.6281 - dsc: 0.3554
#
# Epoch 00015: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 155s 2s/step - loss: 0.6583 - dsc: 0.3880 - val_loss: 0.6884 - val_dsc: 0.3554
# Epoch 16/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6517 - dsc: 0.3957Epoch 1/50
# 157/100 [===============================================] - 55s 351ms/step - loss: 0.5824 - dsc: 0.3533
#
# Epoch 00016: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6522 - dsc: 0.3950 - val_loss: 0.6918 - val_dsc: 0.3533
# Epoch 17/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6434 - dsc: 0.3983Epoch 1/50
# 157/100 [===============================================] - 54s 344ms/step - loss: 0.7920 - dsc: 0.2892
#
# Epoch 00017: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6421 - dsc: 0.3996 - val_loss: 0.7625 - val_dsc: 0.2892
# Epoch 18/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6657 - dsc: 0.3790Epoch 1/50
# 157/100 [===============================================] - 55s 348ms/step - loss: 0.7926 - dsc: 0.2229
#
# Epoch 00018: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6645 - dsc: 0.3801 - val_loss: 0.8278 - val_dsc: 0.2229
# Epoch 19/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6696 - dsc: 0.3751Epoch 1/50
# 157/100 [===============================================] - 55s 349ms/step - loss: 0.6331 - dsc: 0.3828
#
# Epoch 00019: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6701 - dsc: 0.3749 - val_loss: 0.6635 - val_dsc: 0.3828
# Epoch 20/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6267 - dsc: 0.4175Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.6334 - dsc: 0.3698
#
# Epoch 00020: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6295 - dsc: 0.4147 - val_loss: 0.6799 - val_dsc: 0.3698
# Epoch 21/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6158 - dsc: 0.4298Epoch 1/50
# 157/100 [===============================================] - 55s 347ms/step - loss: 0.7071 - dsc: 0.3538
#
# Epoch 00021: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6143 - dsc: 0.4311 - val_loss: 0.6972 - val_dsc: 0.3538
# Epoch 22/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6526 - dsc: 0.3974Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.7359 - dsc: 0.3130
#
# Epoch 00022: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6537 - dsc: 0.3962 - val_loss: 0.7456 - val_dsc: 0.3130
# Epoch 23/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6245 - dsc: 0.4160Epoch 1/50
# 157/100 [===============================================] - 53s 339ms/step - loss: 0.6486 - dsc: 0.4079
#
# Epoch 00023: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.6240 - dsc: 0.4166 - val_loss: 0.6374 - val_dsc: 0.4079
# Epoch 24/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6114 - dsc: 0.4320Epoch 1/50
# 157/100 [===============================================] - 54s 342ms/step - loss: 0.6441 - dsc: 0.4219
#
# Epoch 00024: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.6139 - dsc: 0.4293 - val_loss: 0.6205 - val_dsc: 0.4219
# Epoch 25/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6189 - dsc: 0.4257Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.7509 - dsc: 0.3488
#
# Epoch 00025: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6187 - dsc: 0.4262 - val_loss: 0.7029 - val_dsc: 0.3488
# Epoch 26/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6147 - dsc: 0.4277Epoch 1/50
# 157/100 [===============================================] - 54s 344ms/step - loss: 0.5688 - dsc: 0.4380
#
# Epoch 00026: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.6156 - dsc: 0.4266 - val_loss: 0.6031 - val_dsc: 0.4380
# Epoch 27/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6275 - dsc: 0.4144Epoch 1/50
# 157/100 [===============================================] - 54s 342ms/step - loss: 0.6555 - dsc: 0.4117
#
# Epoch 00027: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6287 - dsc: 0.4136 - val_loss: 0.6271 - val_dsc: 0.4117
# Epoch 28/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6060 - dsc: 0.4363Epoch 1/50
# 157/100 [===============================================] - 54s 341ms/step - loss: 0.5252 - dsc: 0.4407
#
# Epoch 00028: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.6049 - dsc: 0.4373 - val_loss: 0.6017 - val_dsc: 0.4407
# Epoch 29/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6005 - dsc: 0.4397Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.7891 - dsc: 0.3045
#
# Epoch 00029: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.5991 - dsc: 0.4413 - val_loss: 0.7722 - val_dsc: 0.3045
# Epoch 30/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5958 - dsc: 0.4499Epoch 1/50
# 157/100 [===============================================] - 55s 352ms/step - loss: 0.6486 - dsc: 0.4296
#
# Epoch 00030: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.5960 - dsc: 0.4502 - val_loss: 0.6150 - val_dsc: 0.4296
# Epoch 31/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5906 - dsc: 0.4524Epoch 1/50
# 157/100 [===============================================] - 55s 353ms/step - loss: 0.6865 - dsc: 0.3762
#
# Epoch 00031: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.5906 - dsc: 0.4522 - val_loss: 0.6722 - val_dsc: 0.3762
# Epoch 32/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5790 - dsc: 0.4636Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.5755 - dsc: 0.4262
#
# Epoch 00032: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.5826 - dsc: 0.4600 - val_loss: 0.6185 - val_dsc: 0.4262
# Epoch 33/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6122 - dsc: 0.4333Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.6966 - dsc: 0.3635
#
# Epoch 00033: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.6123 - dsc: 0.4335 - val_loss: 0.6941 - val_dsc: 0.3635
# Epoch 34/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5585 - dsc: 0.4794Epoch 1/50
# 157/100 [===============================================] - 53s 340ms/step - loss: 0.6046 - dsc: 0.4514
#
# Epoch 00034: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.5576 - dsc: 0.4806 - val_loss: 0.5864 - val_dsc: 0.4514
# Epoch 35/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5554 - dsc: 0.4818Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.6259 - dsc: 0.3254
#
# Epoch 00035: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.5543 - dsc: 0.4828 - val_loss: 0.7237 - val_dsc: 0.3254
# Epoch 36/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6005 - dsc: 0.4412Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.6411 - dsc: 0.3978
#
# Epoch 00036: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6025 - dsc: 0.4393 - val_loss: 0.6380 - val_dsc: 0.3978
# Epoch 37/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5623 - dsc: 0.4774Epoch 1/50
# 157/100 [===============================================] - 55s 349ms/step - loss: 0.5852 - dsc: 0.4703
#
# Epoch 00037: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.5605 - dsc: 0.4791 - val_loss: 0.5681 - val_dsc: 0.4703
# Epoch 38/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5723 - dsc: 0.4681Epoch 1/50
# 157/100 [===============================================] - 54s 343ms/step - loss: 0.6188 - dsc: 0.4453
#
# Epoch 00038: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.5708 - dsc: 0.4696 - val_loss: 0.6019 - val_dsc: 0.4453
# Epoch 39/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5594 - dsc: 0.4844Epoch 1/50
# 157/100 [===============================================] - 54s 342ms/step - loss: 0.5952 - dsc: 0.4428
#
# Epoch 00039: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.5577 - dsc: 0.4864 - val_loss: 0.5995 - val_dsc: 0.4428
# Epoch 40/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5652 - dsc: 0.4733Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.5293 - dsc: 0.4724
#
# Epoch 00040: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.5662 - dsc: 0.4731 - val_loss: 0.5695 - val_dsc: 0.4724
# Epoch 41/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5660 - dsc: 0.4708Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.5814 - dsc: 0.4464
#
# Epoch 00041: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 155s 2s/step - loss: 0.5689 - dsc: 0.4678 - val_loss: 0.5939 - val_dsc: 0.4464
# Epoch 42/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5988 - dsc: 0.4419Epoch 1/50
# 157/100 [===============================================] - 55s 348ms/step - loss: 0.5509 - dsc: 0.4524
#
# Epoch 00042: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6010 - dsc: 0.4397 - val_loss: 0.5900 - val_dsc: 0.4524
# Epoch 43/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5680 - dsc: 0.4714Epoch 1/50
# 157/100 [===============================================] - 54s 342ms/step - loss: 0.6205 - dsc: 0.4217
#
# Epoch 00043: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 152s 2s/step - loss: 0.5675 - dsc: 0.4720 - val_loss: 0.6376 - val_dsc: 0.4217
# Epoch 44/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5466 - dsc: 0.4943Epoch 1/50
# 157/100 [===============================================] - 56s 355ms/step - loss: 0.6246 - dsc: 0.4210
#
# Epoch 00044: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 155s 2s/step - loss: 0.5471 - dsc: 0.4938 - val_loss: 0.6204 - val_dsc: 0.4210
# Epoch 45/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5493 - dsc: 0.4903Epoch 1/50
# 157/100 [===============================================] - 55s 348ms/step - loss: 0.5504 - dsc: 0.4755
#
# Epoch 00045: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.5502 - dsc: 0.4893 - val_loss: 0.5618 - val_dsc: 0.4755
# Epoch 46/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5341 - dsc: 0.5055Epoch 1/50
# 157/100 [===============================================] - 55s 350ms/step - loss: 0.6185 - dsc: 0.3950
#
# Epoch 00046: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.5344 - dsc: 0.5052 - val_loss: 0.6520 - val_dsc: 0.3950
# Epoch 47/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5346 - dsc: 0.5039Epoch 1/50
# 157/100 [===============================================] - 54s 347ms/step - loss: 0.6391 - dsc: 0.4093
#
# Epoch 00047: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.5342 - dsc: 0.5043 - val_loss: 0.6483 - val_dsc: 0.4093
# Epoch 48/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5022 - dsc: 0.5357Epoch 1/50
# 157/100 [===============================================] - 55s 353ms/step - loss: 0.5604 - dsc: 0.4757
#
# Epoch 00048: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.5027 - dsc: 0.5354 - val_loss: 0.5620 - val_dsc: 0.4757
# Epoch 49/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5708 - dsc: 0.4681Epoch 1/50
# 157/100 [===============================================] - 54s 347ms/step - loss: 0.6563 - dsc: 0.4373
#
# Epoch 00049: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.5696 - dsc: 0.4691 - val_loss: 0.6084 - val_dsc: 0.4373
# Epoch 50/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5510 - dsc: 0.4858Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.6352 - dsc: 0.3573
#
# Epoch 00050: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.5519 - dsc: 0.4852 - val_loss: 0.6903 - val_dsc: 0.3573

# %% [markdown]
# # Output & Visulisation

# %%
history = results

# %%
import matplotlib.pyplot as plt

# list all data in history
print(history.history.keys())
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'dsc', 'val_loss', 'val_dsc'])

# %%
import matplotlib.pyplot as plt

# list all data in history
print(history.history.keys())
# summarize history for loss
plt.plot(history.history['dsc'])
plt.plot(history.history['val_dsc'])
plt.title('Model Dice Metrics')
plt.ylabel('dsc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'dsc', 'val_loss', 'val_dsc'])

# %%
results_output = pd.DataFrame()

# %%
results_output["Epoch"] = list(range(1,51))
results_output['Loss'] = history.history['loss']
results_output['Dice Metrics'] = history.history['dsc'] 
results_output['Validation Loss'] = history.history['val_loss'] 
results_output['Validation Dice Metrics'] = history.history['val_dsc']

# %%
results_output  = results_output.round(3)

# %%
results_output
# Out:
#     Epoch   Loss  Dice Metrics  Validation Loss  Validation Dice Metrics
# 0       1  0.998         0.112            3.433                    0.055
# 1       2  0.879         0.176            1.708                    0.061
# 2       3  0.874         0.187            1.173                    0.101
# 3       4  0.833         0.227            1.010                    0.130
# 4       5  0.795         0.259            0.919                    0.135
# 5       6  0.755         0.298            0.905                    0.140
# 6       7  0.716         0.334            0.879                    0.182
# 7       8  0.736         0.318            1.842                    0.069
# 8       9  0.744         0.305            0.828                    0.233
# 9      10  0.710         0.339            0.671                    0.374
# 10     11  0.686         0.365            0.831                    0.244
# 11     12  0.679         0.368            0.840                    0.249
# 12     13  0.671         0.379            0.907                    0.208
# 13     14  0.648         0.400            0.717                    0.333
# 14     15  0.658         0.388            0.688                    0.355
# 15     16  0.652         0.395            0.692                    0.353
# 16     17  0.642         0.400            0.763                    0.289
# 17     18  0.664         0.380            0.828                    0.223
# 18     19  0.670         0.375            0.664                    0.383
# 19     20  0.629         0.415            0.680                    0.370
# 20     21  0.614         0.431            0.697                    0.354
# 21     22  0.654         0.396            0.746                    0.313
# 22     23  0.624         0.417            0.637                    0.408
# 23     24  0.614         0.429            0.621                    0.422
# 24     25  0.619         0.426            0.703                    0.349
# 25     26  0.616         0.427            0.603                    0.438
# 26     27  0.629         0.414            0.627                    0.412
# 27     28  0.605         0.437            0.602                    0.441
# 28     29  0.599         0.441            0.772                    0.305
# 29     30  0.596         0.450            0.615                    0.430
# 30     31  0.591         0.452            0.672                    0.376
# 31     32  0.583         0.460            0.619                    0.426
# 32     33  0.612         0.433            0.694                    0.363
# 33     34  0.558         0.481            0.586                    0.451
# 34     35  0.554         0.483            0.724                    0.325
# 35     36  0.602         0.439            0.638                    0.398
# 36     37  0.560         0.479            0.568                    0.470
# 37     38  0.571         0.470            0.602                    0.445
# 38     39  0.558         0.486            0.599                    0.443
# 39     40  0.566         0.473            0.570                    0.472
# 40     41  0.569         0.468            0.594                    0.446
# 41     42  0.601         0.440            0.590                    0.452
# 42     43  0.567         0.472            0.638                    0.422
# 43     44  0.547         0.494            0.620                    0.421
# 44     45  0.550         0.489            0.562                    0.476
# 45     46  0.534         0.505            0.652                    0.395
# 46     47  0.534         0.504            0.648                    0.409
# 47     48  0.503         0.535            0.562                    0.476
# 48     49  0.570         0.469            0.608                    0.437
# 49     50  0.552         0.485            0.690                    0.357

# %%
results_output.to_csv(path + "SDA_RESNET_Pretrain_Code.csv")
