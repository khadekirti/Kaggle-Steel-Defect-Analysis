# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from tqdm import tqdm_notebook
import cv2

import keras
from keras.layers.convolutional import Conv2DTranspose
from keras.layers.merge import concatenate
from keras.layers import UpSampling2D, Conv2D, Activation, Input, Dropout, MaxPooling2D
from keras import Model
from keras import backend as K
from keras.layers.core import Lambda
from collections import defaultdict
from sklearn.model_selection import train_test_split
import pandas as pd

import random

import tensorflow as tf
from tensorflow import reduce_sum
from tensorflow.keras.backend import pow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, UpSampling2D, Concatenate, Add, Flatten
from tensorflow.keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from tensorflow.keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Get Data

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········

# %%
path = '/content/drive/My Drive/project/data_main/'

# %%
train_img = path + "train_images"

# %%
train_data  = pd.read_csv(path + '/train.csv')
print("Length of train data", len(train_data))

# %%
# Pivot the data
df = pd.read_csv(path + '/train.csv')
df['ImageId'], df['ClassId'] = zip(*df['ImageId_ClassId'].str.split('_'))
df['ClassId'] = df['ClassId'].astype(int)
df = df.pivot(index='ImageId',columns='ClassId',values='EncodedPixels')
df['defects'] = df.count(axis=1)
# Divide the data 
train_df, val_df = train_test_split(df, test_size=0.2, stratify=df["defects"], random_state=69)

# %%
train_df = train_df.reset_index()
train_df = train_df.reset_index()

val_df = val_df.reset_index()
val_df = val_df.reset_index()

# %%
# For class imbalance, we need to use the data witout nulls.
df_no_null = train_data[train_data['EncodedPixels'].notnull()].reset_index(drop=True)
 
print("Lenght of training data " , len(train_df))
print("Lenght of validation data " , len(val_df))

# %% [markdown]
# # Pre-process data

# %%
def mask2rle(img):
    '''
    For an ouput numpy array
    1  == Mask, 
    0  == background
    Returns run length as string formated
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
def make_mask(row_id, df):
    '''
    Given a row index, 
    return a image id and mask of the image in the format of (256, 1600, 4)
    from the dataframe `df`
    '''

    masks = np.zeros((256, 1600, 4), dtype=np.float32)     
    labels = df.iloc[row_id][2:-1]
    for idx, label in enumerate(labels.values):
        if label is not np.nan:
            label = label.split(" ")
            positions = map(int, label[0::2])
            length = map(int, label[1::2])
            mask = np.zeros(256 * 1600, dtype=np.uint8)
            for pos, le in zip(positions, length):
                mask[pos:(pos + le)] = 1
            masks[:, :, idx] = mask.reshape(256, 1600, order='F')
    return masks

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, df, image_dir, batch_size=16,
                 img_h=256, img_w=256, shuffle=True):
        
        self.df = df
        self.image_dir = image_dir
        self.batch_size = batch_size
        self.img_h = img_h
        self.img_w = img_w
        self.shuffle = shuffle
        self.on_epoch_end()
    
    def __len__(self):
        'denotes the number of batches per epoch'
        return int(np.floor(len(self.df)) / self.batch_size)
    
    def __getitem__(self, index):
        'generate one batch of data'
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # get list of IDs
        list_ids_temp = indexes
        # generate data
        X, y = self.__data_generation(list_ids_temp)
        # return data 
        return X, y
    
    def on_epoch_end(self):
        'update ended after each epoch'
        self.indexes = np.arange(len(self.df))
        if self.shuffle:
            np.random.shuffle(self.indexes)
            
    def __data_generation(self, list_ids_temp):
      img_size = 256
      x_batch = []
      y_batch = []
      for id in list_ids_temp: 
          # Get the image
          image_name = self.df['ImageId'].iloc[id]
          image = cv2.imread(self.image_dir  + 'train_images/'+image_name)
          image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
          # Get the mask 
          mask = make_mask(id, self.df)
          # Resize 
          image = cv2.resize(image, (img_size, img_size))
          mask = cv2.resize(mask, (img_size, img_size))
          # Add 
          x_batch += [image]
          y_batch += [mask]
      # Change to numpy                   
      x_batch = np.array(x_batch)
      y_batch = np.array(y_batch)
      return x_batch, y_batch

# %%
training_generator = DataGenerator(train_df, path)

# %%
validation_generator = DataGenerator(val_df, path)

# %%
def class_imbalance(df): 
  '''
  To treat for class imbalance, we will be using this function
  '''
  # Get the data, arrange it in classes 
  df['ImageId'], df['ClassId'] = zip(*df['ImageId_ClassId'].str.split('_'))
  df['ClassId'] = df['ClassId'].astype(int)
  df = df.pivot(index='ImageId',columns='ClassId',values='EncodedPixels')
  df['defects'] = df.count(axis=1) 
  # Get the number of mask in each class 
  list_all = list(df.count())[: -1]
  sum_list_all = sum(list_all) 
  return [list_all[i]/sum_list_all * 4  for i in range(len(list_all))]

# %% [markdown]
# # Model

# %%
def dsc(y_true, y_pred, smooth=1):
    '''
    Get the dice coefficiant of two oututs 
    '''
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth) 
  
def dice_loss(y_true, y_pred):
    '''
    Get the loss 
    '''
    loss = 1 - dsc(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    '''
    Get the loss
    '''
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
def bn_act(x, act=True):
    'batch normalization layer with an optinal activation layer'
    x = tf.keras.layers.BatchNormalization()(x)
    if act == True:
        x = tf.keras.layers.Activation('relu')(x)
    return x

def conv_block(x, filters, kernel_size=3, padding='same', strides=1):
    'convolutional layer which always uses the batch normalization layer'
    conv = bn_act(x)
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv
  
def stem(x, filters, kernel_size=3, padding='same', strides=1):
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size, padding, strides)
    shortcut = Conv2D(filters, kernel_size=1, padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    output = Add()([conv, shortcut])
    return output 
  
def residual_block(x, filters, kernel_size=3, padding='same', strides=1):
    res = conv_block(x, filters, k_size, padding, strides)
    res = conv_block(res, filters, k_size, padding, 1)
    shortcut = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    output = Add()([shortcut, res])
    return output 
  
def upsample_concat_block(x, xskip):
    u = UpSampling2D((2,2))(x)
    c = Concatenate()([u, xskip])
    return c 
  


def ResUNet(img_h, img_w):
    f = [16, 32, 64, 128, 256]
    inputs = Input((img_h, img_w, 3))
    
    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)
    
    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)
    
    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = tf.keras.layers.Conv2D(4, (1, 1), padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs)
    return model

# %%
k_size = 3
model = ResUNet(img_h=256, img_w= 256)
adam = tf.keras.optimizers.Adam(lr = 0.05, epsilon = 0.1)
model.compile(optimizer=adam, loss=bce_dice_loss, metrics=[dsc])
#model.load_weights(path + 'ResUNetSteel_w800e50_z.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.summary()

# %% [markdown]
# # Test & Train

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint = ModelCheckpoint(path + 'model_best_weights_resnet.h5', monitor='loss', verbose=1, save_best_only=False, mode='min', period=1)

# %%
batch_size = 16
results = model.fit_generator(generator=training_generator, 
                              validation_data=validation_generator,
                              steps_per_epoch= 100,
                              epochs=50, callbacks = [checkpoint],)
# Out:
# Epoch 1/50
#  99/100 [============================>.] - ETA: 5s - loss: 1.0048 - dsc: 0.1197 Epoch 1/50
# 157/100 [===============================================] - 989s 6s/step - loss: 0.9625 - dsc: 0.0821
#
# Epoch 00001: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 1583s 16s/step - loss: 1.0021 - dsc: 0.1216 - val_loss: 0.9961 - val_dsc: 0.0821
# Epoch 2/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8473 - dsc: 0.2169Epoch 1/50
# 157/100 [===============================================] - 58s 368ms/step - loss: 0.9963 - dsc: 0.0842
#
# Epoch 00002: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 544s 5s/step - loss: 0.8485 - dsc: 0.2158 - val_loss: 0.9817 - val_dsc: 0.0842
# Epoch 3/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8553 - dsc: 0.2027Epoch 1/50
# 157/100 [===============================================] - 57s 364ms/step - loss: 0.8529 - dsc: 0.1905
#
# Epoch 00003: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 541s 5s/step - loss: 0.8539 - dsc: 0.2047 - val_loss: 0.8679 - val_dsc: 0.1905
# Epoch 4/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8501 - dsc: 0.2092Epoch 1/50
# 157/100 [===============================================] - 57s 364ms/step - loss: 1.0209 - dsc: 0.1273
#
# Epoch 00004: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 556s 6s/step - loss: 0.8472 - dsc: 0.2120 - val_loss: 1.0229 - val_dsc: 0.1273
# Epoch 5/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8378 - dsc: 0.2208Epoch 1/50
# 157/100 [===============================================] - 57s 363ms/step - loss: 1.0527 - dsc: 0.1031
#
# Epoch 00005: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 542s 5s/step - loss: 0.8362 - dsc: 0.2222 - val_loss: 1.0453 - val_dsc: 0.1031
# Epoch 6/50
#  99/100 [============================>.] - ETA: 4s - loss: 0.8191 - dsc: 0.2361Epoch 1/50
# 157/100 [===============================================] - 57s 361ms/step - loss: 0.8060 - dsc: 0.2252
#
# Epoch 00006: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 545s 5s/step - loss: 0.8197 - dsc: 0.2358 - val_loss: 0.8351 - val_dsc: 0.2252
# Epoch 7/50
#  99/100 [============================>.] - ETA: 1s - loss: 0.7600 - dsc: 0.2913Epoch 1/50
# 157/100 [===============================================] - 55s 347ms/step - loss: 0.7738 - dsc: 0.1810
#
# Epoch 00007: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 226s 2s/step - loss: 0.7608 - dsc: 0.2903 - val_loss: 0.8824 - val_dsc: 0.1810
# Epoch 8/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.7173 - dsc: 0.3313Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.7251 - dsc: 0.2687
#
# Epoch 00008: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.7192 - dsc: 0.3299 - val_loss: 0.7820 - val_dsc: 0.2687
# Epoch 9/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.7350 - dsc: 0.3144Epoch 1/50
# 157/100 [===============================================] - 55s 350ms/step - loss: 0.7430 - dsc: 0.2814
#
# Epoch 00009: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.7352 - dsc: 0.3141 - val_loss: 0.7683 - val_dsc: 0.2814
# Epoch 10/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6985 - dsc: 0.3513Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.7918 - dsc: 0.3342
#
# Epoch 00010: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6993 - dsc: 0.3508 - val_loss: 0.7112 - val_dsc: 0.3342
# Epoch 11/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6997 - dsc: 0.3497Epoch 1/50
# 157/100 [===============================================] - 55s 350ms/step - loss: 0.7431 - dsc: 0.3390
#
# Epoch 00011: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.7014 - dsc: 0.3478 - val_loss: 0.7098 - val_dsc: 0.3390
# Epoch 12/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6917 - dsc: 0.3573Epoch 1/50
# 157/100 [===============================================] - 54s 346ms/step - loss: 0.7146 - dsc: 0.3630
#
# Epoch 00012: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6917 - dsc: 0.3574 - val_loss: 0.6837 - val_dsc: 0.3630
# Epoch 13/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6666 - dsc: 0.3835Epoch 1/50
# 157/100 [===============================================] - 55s 352ms/step - loss: 0.7475 - dsc: 0.3583
#
# Epoch 00013: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6663 - dsc: 0.3837 - val_loss: 0.6923 - val_dsc: 0.3583
# Epoch 14/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6542 - dsc: 0.3923Epoch 1/50
# 157/100 [===============================================] - 55s 348ms/step - loss: 0.7532 - dsc: 0.2727
#
# Epoch 00014: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 156s 2s/step - loss: 0.6546 - dsc: 0.3921 - val_loss: 0.7769 - val_dsc: 0.2727
# Epoch 15/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6473 - dsc: 0.4015Epoch 1/50
# 157/100 [===============================================] - 55s 351ms/step - loss: 0.8946 - dsc: 0.1756
#
# Epoch 00015: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6461 - dsc: 0.4027 - val_loss: 0.8735 - val_dsc: 0.1756
# Epoch 16/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6587 - dsc: 0.3874Epoch 1/50
# 157/100 [===============================================] - 54s 342ms/step - loss: 0.7789 - dsc: 0.2856
#
# Epoch 00016: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6591 - dsc: 0.3868 - val_loss: 0.7852 - val_dsc: 0.2856
# Epoch 17/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6727 - dsc: 0.3741Epoch 1/50
# 157/100 [===============================================] - 55s 353ms/step - loss: 0.5865 - dsc: 0.3823
#
# Epoch 00017: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 155s 2s/step - loss: 0.6755 - dsc: 0.3715 - val_loss: 0.6575 - val_dsc: 0.3823
# Epoch 18/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6704 - dsc: 0.3744Epoch 1/50
# 157/100 [===============================================] - 54s 343ms/step - loss: 0.6960 - dsc: 0.3775
#
# Epoch 00018: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6677 - dsc: 0.3771 - val_loss: 0.6697 - val_dsc: 0.3775
# Epoch 19/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6506 - dsc: 0.3944Epoch 1/50
# 157/100 [===============================================] - 55s 349ms/step - loss: 0.6523 - dsc: 0.3859
#
# Epoch 00019: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.6504 - dsc: 0.3944 - val_loss: 0.6589 - val_dsc: 0.3859
# Epoch 20/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6144 - dsc: 0.4319Epoch 1/50
# 157/100 [===============================================] - 54s 345ms/step - loss: 0.6867 - dsc: 0.3654
#
# Epoch 00020: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 153s 2s/step - loss: 0.6112 - dsc: 0.4349 - val_loss: 0.6924 - val_dsc: 0.3654
# Epoch 21/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6466 - dsc: 0.3967Epoch 1/50
# 157/100 [===============================================] - 57s 366ms/step - loss: 0.6979 - dsc: 0.3095
#
# Epoch 00021: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 157s 2s/step - loss: 0.6449 - dsc: 0.3982 - val_loss: 0.7422 - val_dsc: 0.3095
# Epoch 22/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6501 - dsc: 0.3936Epoch 1/50
# 157/100 [===============================================] - 58s 372ms/step - loss: 0.7047 - dsc: 0.3916
#
# Epoch 00022: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.6511 - dsc: 0.3925 - val_loss: 0.6540 - val_dsc: 0.3916
# Epoch 23/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6281 - dsc: 0.4144Epoch 1/50
# 157/100 [===============================================] - 59s 376ms/step - loss: 0.6873 - dsc: 0.3512
#
# Epoch 00023: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.6278 - dsc: 0.4146 - val_loss: 0.6972 - val_dsc: 0.3512
# Epoch 24/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6167 - dsc: 0.4294Epoch 1/50
# 157/100 [===============================================] - 60s 381ms/step - loss: 0.7736 - dsc: 0.3635
#
# Epoch 00024: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.6163 - dsc: 0.4297 - val_loss: 0.6837 - val_dsc: 0.3635
# Epoch 25/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6250 - dsc: 0.4204Epoch 1/50
# 157/100 [===============================================] - 60s 383ms/step - loss: 0.5930 - dsc: 0.4242
#
# Epoch 00025: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 160s 2s/step - loss: 0.6254 - dsc: 0.4200 - val_loss: 0.6142 - val_dsc: 0.4242
# Epoch 26/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6302 - dsc: 0.4139Epoch 1/50
# 157/100 [===============================================] - 60s 381ms/step - loss: 0.6471 - dsc: 0.4175
#
# Epoch 00026: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 160s 2s/step - loss: 0.6328 - dsc: 0.4118 - val_loss: 0.6291 - val_dsc: 0.4175
# Epoch 27/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6025 - dsc: 0.4400Epoch 1/50
# 157/100 [===============================================] - 60s 382ms/step - loss: 0.6655 - dsc: 0.3832
#
# Epoch 00027: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 163s 2s/step - loss: 0.6001 - dsc: 0.4421 - val_loss: 0.6616 - val_dsc: 0.3832
# Epoch 28/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5955 - dsc: 0.4479Epoch 1/50
# 157/100 [===============================================] - 58s 367ms/step - loss: 0.5515 - dsc: 0.4141
#
# Epoch 00028: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 157s 2s/step - loss: 0.5944 - dsc: 0.4490 - val_loss: 0.6246 - val_dsc: 0.4141
# Epoch 29/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5868 - dsc: 0.4564Epoch 1/50
# 157/100 [===============================================] - 60s 383ms/step - loss: 0.6512 - dsc: 0.4225
#
# Epoch 00029: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.5883 - dsc: 0.4556 - val_loss: 0.6247 - val_dsc: 0.4225
# Epoch 30/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6356 - dsc: 0.4083Epoch 1/50
# 157/100 [===============================================] - 59s 374ms/step - loss: 0.6186 - dsc: 0.4403
#
# Epoch 00030: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.6359 - dsc: 0.4078 - val_loss: 0.6012 - val_dsc: 0.4403
# Epoch 31/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.6093 - dsc: 0.4314Epoch 1/50
# 157/100 [===============================================] - 58s 370ms/step - loss: 0.7055 - dsc: 0.4116
#
# Epoch 00031: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 157s 2s/step - loss: 0.6090 - dsc: 0.4316 - val_loss: 0.6350 - val_dsc: 0.4116
# Epoch 32/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5733 - dsc: 0.4669Epoch 1/50
# 157/100 [===============================================] - 56s 359ms/step - loss: 0.6577 - dsc: 0.4104
#
# Epoch 00032: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 156s 2s/step - loss: 0.5731 - dsc: 0.4669 - val_loss: 0.6321 - val_dsc: 0.4104
# Epoch 33/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5743 - dsc: 0.4646Epoch 1/50
# 157/100 [===============================================] - 60s 383ms/step - loss: 0.5758 - dsc: 0.4358
#
# Epoch 00033: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.5728 - dsc: 0.4661 - val_loss: 0.6023 - val_dsc: 0.4358
# Epoch 34/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5929 - dsc: 0.4518Epoch 1/50
# 157/100 [===============================================] - 59s 373ms/step - loss: 0.6019 - dsc: 0.3954
#
# Epoch 00034: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.5919 - dsc: 0.4524 - val_loss: 0.6615 - val_dsc: 0.3954
# Epoch 35/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5868 - dsc: 0.4557Epoch 1/50
# 157/100 [===============================================] - 58s 371ms/step - loss: 0.7453 - dsc: 0.3681
#
# Epoch 00035: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.5881 - dsc: 0.4546 - val_loss: 0.6835 - val_dsc: 0.3681
# Epoch 36/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5955 - dsc: 0.4435Epoch 1/50
# 157/100 [===============================================] - 58s 372ms/step - loss: 0.5936 - dsc: 0.4327
#
# Epoch 00036: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.5936 - dsc: 0.4453 - val_loss: 0.6089 - val_dsc: 0.4327
# Epoch 37/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5682 - dsc: 0.4747Epoch 1/50
# 157/100 [===============================================] - 60s 379ms/step - loss: 0.7211 - dsc: 0.3855
#
# Epoch 00037: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.5693 - dsc: 0.4739 - val_loss: 0.6724 - val_dsc: 0.3855
# Epoch 38/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5750 - dsc: 0.4661Epoch 1/50
# 157/100 [===============================================] - 58s 368ms/step - loss: 0.5442 - dsc: 0.4615
#
# Epoch 00038: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 157s 2s/step - loss: 0.5741 - dsc: 0.4668 - val_loss: 0.5794 - val_dsc: 0.4615
# Epoch 39/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5587 - dsc: 0.4809Epoch 1/50
# 157/100 [===============================================] - 59s 378ms/step - loss: 0.6213 - dsc: 0.4203
#
# Epoch 00039: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 169s 2s/step - loss: 0.5587 - dsc: 0.4809 - val_loss: 0.6231 - val_dsc: 0.4203
# Epoch 40/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5624 - dsc: 0.4772Epoch 1/50
# 157/100 [===============================================] - 59s 376ms/step - loss: 0.5390 - dsc: 0.4555
#
# Epoch 00040: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.5624 - dsc: 0.4775 - val_loss: 0.5827 - val_dsc: 0.4555
# Epoch 41/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5692 - dsc: 0.4728Epoch 1/50
# 157/100 [===============================================] - 59s 375ms/step - loss: 0.7257 - dsc: 0.3641
#
# Epoch 00041: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.5687 - dsc: 0.4734 - val_loss: 0.6974 - val_dsc: 0.3641
# Epoch 42/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5685 - dsc: 0.4706Epoch 1/50
# 157/100 [===============================================] - 58s 368ms/step - loss: 0.7659 - dsc: 0.2947
#
# Epoch 00042: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 157s 2s/step - loss: 0.5689 - dsc: 0.4702 - val_loss: 0.7602 - val_dsc: 0.2947
# Epoch 43/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5612 - dsc: 0.4793Epoch 1/50
# 157/100 [===============================================] - 58s 369ms/step - loss: 0.8401 - dsc: 0.2512
#
# Epoch 00043: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.5580 - dsc: 0.4823 - val_loss: 0.8644 - val_dsc: 0.2512
# Epoch 44/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5779 - dsc: 0.4651Epoch 1/50
# 157/100 [===============================================] - 59s 378ms/step - loss: 0.6202 - dsc: 0.4555
#
# Epoch 00044: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.5746 - dsc: 0.4681 - val_loss: 0.5803 - val_dsc: 0.4555
# Epoch 45/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5296 - dsc: 0.5055Epoch 1/50
# 157/100 [===============================================] - 59s 376ms/step - loss: 0.5649 - dsc: 0.4643
#
# Epoch 00045: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 158s 2s/step - loss: 0.5288 - dsc: 0.5062 - val_loss: 0.5762 - val_dsc: 0.4643
# Epoch 46/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5480 - dsc: 0.4928Epoch 1/50
# 157/100 [===============================================] - 59s 377ms/step - loss: 0.5594 - dsc: 0.4904
#
# Epoch 00046: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 159s 2s/step - loss: 0.5471 - dsc: 0.4937 - val_loss: 0.5497 - val_dsc: 0.4904
# Epoch 47/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5389 - dsc: 0.5013Epoch 1/50
# 157/100 [===============================================] - 56s 358ms/step - loss: 0.7174 - dsc: 0.4174
#
# Epoch 00047: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 156s 2s/step - loss: 0.5396 - dsc: 0.5006 - val_loss: 0.6283 - val_dsc: 0.4174
# Epoch 48/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5383 - dsc: 0.5021Epoch 1/50
# 157/100 [===============================================] - 57s 363ms/step - loss: 0.5701 - dsc: 0.4717
#
# Epoch 00048: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 157s 2s/step - loss: 0.5377 - dsc: 0.5026 - val_loss: 0.5674 - val_dsc: 0.4717
# Epoch 49/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5573 - dsc: 0.4814Epoch 1/50
# 157/100 [===============================================] - 57s 362ms/step - loss: 0.6305 - dsc: 0.3959
#
# Epoch 00049: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 156s 2s/step - loss: 0.5573 - dsc: 0.4817 - val_loss: 0.6672 - val_dsc: 0.3959
# Epoch 50/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.5468 - dsc: 0.4921Epoch 1/50
# 157/100 [===============================================] - 55s 351ms/step - loss: 0.5255 - dsc: 0.4867
#
# Epoch 00050: saving model to /content/drive/My Drive/project/data_main/model_best_weights_resnet.h5
# 100/100 [==============================] - 154s 2s/step - loss: 0.5491 - dsc: 0.4895 - val_loss: 0.5517 - val_dsc: 0.4867

# %% [markdown]
# # Output & Visulisation

# %%
history = results

# %%
import matplotlib.pyplot as plt

# list all data in history
print(history.history.keys())
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'dsc', 'val_loss', 'val_dsc'])

# %%
import matplotlib.pyplot as plt

# list all data in history
print(history.history.keys())
# summarize history for loss
plt.plot(history.history['dsc'])
plt.plot(history.history['val_dsc'])
plt.title('Model Dice Metrics')
plt.ylabel('dsc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'dsc', 'val_loss', 'val_dsc'])

# %%
results_output = pd.DataFrame()

# %%
results_output["Epoch"] = list(range(1,51))
results_output['Loss'] = history.history['loss']
results_output['Dice Metrics'] = history.history['dsc'] 
results_output['Validation Loss'] = history.history['val_loss'] 
results_output['Validation Dice Metrics'] = history.history['val_dsc']

# %%
results_output  = results_output.round(3)

# %%
results_output
# Out:
#     Epoch   Loss  Dice Metrics  Validation Loss  Validation Dice Metrics
# 0       1  1.002         0.122            0.996                    0.082
# 1       2  0.848         0.216            0.982                    0.084
# 2       3  0.854         0.205            0.868                    0.190
# 3       4  0.847         0.212            1.023                    0.127
# 4       5  0.836         0.222            1.045                    0.103
# 5       6  0.820         0.236            0.835                    0.225
# 6       7  0.761         0.290            0.882                    0.181
# 7       8  0.719         0.330            0.782                    0.269
# 8       9  0.735         0.314            0.768                    0.281
# 9      10  0.699         0.351            0.711                    0.334
# 10     11  0.701         0.348            0.710                    0.339
# 11     12  0.692         0.357            0.684                    0.363
# 12     13  0.666         0.384            0.692                    0.358
# 13     14  0.655         0.392            0.777                    0.273
# 14     15  0.646         0.403            0.873                    0.176
# 15     16  0.659         0.387            0.785                    0.286
# 16     17  0.676         0.371            0.658                    0.382
# 17     18  0.668         0.377            0.670                    0.377
# 18     19  0.650         0.394            0.659                    0.386
# 19     20  0.611         0.435            0.692                    0.365
# 20     21  0.645         0.398            0.742                    0.309
# 21     22  0.651         0.392            0.654                    0.392
# 22     23  0.628         0.415            0.697                    0.351
# 23     24  0.616         0.430            0.684                    0.363
# 24     25  0.625         0.420            0.614                    0.424
# 25     26  0.633         0.412            0.629                    0.417
# 26     27  0.600         0.442            0.662                    0.383
# 27     28  0.594         0.449            0.625                    0.414
# 28     29  0.588         0.456            0.625                    0.422
# 29     30  0.636         0.408            0.601                    0.440
# 30     31  0.609         0.432            0.635                    0.412
# 31     32  0.573         0.467            0.632                    0.410
# 32     33  0.573         0.466            0.602                    0.436
# 33     34  0.592         0.452            0.662                    0.395
# 34     35  0.588         0.455            0.684                    0.368
# 35     36  0.594         0.445            0.609                    0.433
# 36     37  0.569         0.474            0.672                    0.385
# 37     38  0.574         0.467            0.579                    0.461
# 38     39  0.559         0.481            0.623                    0.420
# 39     40  0.562         0.478            0.583                    0.456
# 40     41  0.569         0.473            0.697                    0.364
# 41     42  0.569         0.470            0.760                    0.295
# 42     43  0.558         0.482            0.864                    0.251
# 43     44  0.575         0.468            0.580                    0.455
# 44     45  0.529         0.506            0.576                    0.464
# 45     46  0.547         0.494            0.550                    0.490
# 46     47  0.540         0.501            0.628                    0.417
# 47     48  0.538         0.503            0.567                    0.472
# 48     49  0.557         0.482            0.667                    0.396
# 49     50  0.549         0.489            0.552                    0.487

# %%
results_output.to_csv(path + "SDA_RESNET_No_class_imbalance.csv")
